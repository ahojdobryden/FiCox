# %% [markdown]
# # Homework 1

# %% [markdown]
# Daniel Ott (33551440), Samuel Šmíd (73123255), Anna Turnerová (70701808)

# %% [markdown]
# ## Packages

# %%
#install.packages("fBasics")
#install.packages("tidyverse")
#install.packages("moments")

# %%
library(tidyverse)
library(dplyr)
library(ggplot2)
library(moments)
library(fBasics)
library(stabledist)
library(purrr)

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ### Part 1

# %% [markdown]
# We import the data and store each data frame into a list of data frames. To make sure there is a distinction between the data of each student in the group, we add the student code before each ticker

# %%
# 1. Get the full paths for all files inside the HA1 folder and its subfolders
target_folders <- c("33551440","70701808","73123255")
file_paths <- list.files(path = target_folders, full.names = TRUE, pattern = "\\.csv$")

# 2. Read all the files into a single list of data frames
list_of_dfs <- lapply(file_paths, read.csv)

# 3. Extract the folder names and ticker names to create the new labels
folder_names <- basename(dirname(file_paths))
ticker_names <- tools::file_path_sans_ext(basename(file_paths))

# 4. Combine them with an underscore and assign them as the names of the list items
names(list_of_dfs) <- paste(folder_names, ticker_names, sep = "_")

# %%
#inspecting the ticker names in the list
names(list_of_dfs)
# Out:
#  [1] "33551440_AFL"  "33551440_ALGN" "33551440_C"    "33551440_CAT"
#  [5] "33551440_CZR"  "33551440_HIG"  "33551440_ORCL" "33551440_TMO"
#  [9] "33551440_TSCO" "33551440_WAT"  "70701808_AMCR" "70701808_AME"
# [13] "70701808_BA"   "70701808_EQT"  "70701808_KIM"  "70701808_KMI"
# [17] "70701808_LOW"  "70701808_MS"   "70701808_PCAR" "70701808_WAT"
# [21] "73123255_CSGP" "73123255_CTRA" "73123255_ES"   "73123255_MRK"
# [25] "73123255_NOC"  "73123255_ON"   "73123255_ORCL" "73123255_TFC"

# %%
lapply(list_of_dfs, colnames)
# Out:
# $`33551440_AFL`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_ALGN`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_C`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_CAT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_CZR`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_HIG`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_ORCL`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_TMO`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_TSCO`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_WAT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_AMCR`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_AME`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_BA`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_EQT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_KIM`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_KMI`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_LOW`
# [1] "Date"   "Klose"  "Open"   "High"   "Low"    "Volume"
#
# $`70701808_MS`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_PCAR`
# [1] "Date"   "Klose"  "Open"   "High"   "Low"    "Volume"
#
# $`70701808_WAT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_CSGP`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_CTRA`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_ES`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_MRK`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_NOC`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_ON`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_ORCL`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_TFC`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"

# %% [markdown]
# **data celaning:** Upon inspection of the column names, we find that some dataframes contain the column Klose instead of Close. We rename such columns using lapply.

# %%
list_of_dfs <- lapply(list_of_dfs, function(df) {
  names(df)[names(df) == "Klose"] <- "Close"
  df
})

# %% [markdown]
# We check if it worked

# %%
lapply(list_of_dfs, colnames)
# Out:
# $`33551440_AFL`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_ALGN`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_C`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_CAT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_CZR`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_HIG`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_ORCL`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_TMO`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_TSCO`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`33551440_WAT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_AMCR`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_AME`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_BA`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_EQT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_KIM`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_KMI`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_LOW`
# [1] "Date"   "Close"  "Open"   "High"   "Low"    "Volume"
#
# $`70701808_MS`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`70701808_PCAR`
# [1] "Date"   "Close"  "Open"   "High"   "Low"    "Volume"
#
# $`70701808_WAT`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_CSGP`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_CTRA`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_ES`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_MRK`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_NOC`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_ON`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_ORCL`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"
#
# $`73123255_TFC`
# [1] "Date"         "Open"         "High"         "Low"          "Close"
# [6] "Volume"       "Dividends"    "Stock.Splits"

# %% [markdown]
# We move on to further inspection

# %%
lapply(list_of_dfs, nrow)
lapply(list_of_dfs, head)
# Out:
# $`33551440_AFL`
# [1] 1754
#
# $`33551440_ALGN`
# [1] 1759
#
# $`33551440_C`
# [1] 1759
#
# $`33551440_CAT`
# [1] 1759
#
# $`33551440_CZR`
# [1] 1759
#
# $`33551440_HIG`
# [1] 1759
#
# $`33551440_ORCL`
# [1] 1756
#
# $`33551440_TMO`
# [1] 1759
#
# $`33551440_TSCO`
# [1] 1759
#
# $`33551440_WAT`
# [1] 1759
#
# $`70701808_AMCR`
# [1] 1759
#
# $`70701808_AME`
# [1] 1759
#
# $`70701808_BA`
# [1] 1757
#
# $`70701808_EQT`
# [1] 1759
#
# $`70701808_KIM`
# [1] 1756
#
# $`70701808_KMI`
# [1] 1756
#
# $`70701808_LOW`
# [1] 1758
#
# $`70701808_MS`
# [1] 1759
#
# $`70701808_PCAR`
# [1] 1759
#
# $`70701808_WAT`
# [1] 1759
#
# $`73123255_CSGP`
# [1] 1756
#
# $`73123255_CTRA`
# [1] 1757
#
# $`73123255_ES`
# [1] 1759
#
# $`73123255_MRK`
# [1] 1759
#
# $`73123255_NOC`
# [1] 1759
#
# $`73123255_ON`
# [1] 1757
#
# $`73123255_ORCL`
# [1] 1758
#
# $`73123255_TFC`
# [1] 1759
# $`33551440_AFL`
#         Date   Open   High    Low  Close  Volume Dividends Stock.Splits
# 1 2019-01-02 37.626 38.462 37.576 38.411 4022100         0            0
# 2 2019-01-03 38.284 38.462 37.365 37.441 4239700         0            0
# 3 2019-01-04 37.989 38.183 37.711 37.905 4761500         0            0
# 4 2019-01-07 37.879 38.495 37.711 38.107 3414400         0            0
# 5 2019-01-08 38.403 38.538 37.829 38.225 3017000         0            0
# 6 2019-01-09 38.386 38.647 38.099 38.141 4501100         0            0
#
# $`33551440_ALGN`
#         Date   Open   High    Low  Close  Volume Dividends Stock.Splits
# 1 2019-01-02 205.32 207.16 200.54 202.12 1126800         0            0
# 2 2019-01-03 200.03 200.77 183.62 184.78 2414200         0            0
# 3 2019-01-04 181.68 190.39 177.93 186.71 2518200         0            0
# 4 2019-01-07 187.41 190.77 184.51 189.92 1311200         0            0
# 5 2019-01-08 191.35 194.99 187.59 192.95 1001500         0            0
# 6 2019-01-09 194.26 207.00 194.26 200.32 1666300         0            0
#
# $`33551440_C`
#         Date   Open   High    Low  Close   Volume Dividends Stock.Splits
# 1 2019-01-02 39.416 41.796 39.408 41.633 21646300         0            0
# 2 2019-01-03 41.539 41.703 40.614 40.878 21183000         0            0
# 3 2019-01-04 42.006 43.071 41.734 42.877 24205100         0            0
# 4 2019-01-07 43.033 43.717 42.620  43.25 20634100         0            0
# 2 2019-01-03 32.052 32.465 31.863 31.95726 3530600         0            0
# 3 2019-01-04 32.523 32.922 32.400 32.78640 3267200         0            0
# 4 2019-01-07 32.711 33.371 32.516 33.04627 3584400         0            0
# 5 2019-01-08 33.190 33.313 32.668 33.12614 3389300         0            0
# 6 2019-01-09 33.226 33.552 33.067 33.43656 5827000         0            0

# %% [markdown]
# We can already suspect missing values in some cases and that the times series begin on 2nd January 2019. Furthermore some series will have missing dates compared to others as the dimensions of some are smaller by a fine margin

# %% [markdown]
# **data cleaning:** We format the Date columns so they are all in the same format

# %%
list_of_dfs <- lapply(list_of_dfs, function(df) {
  # 1. Identify which columns have "Date" in the name
  date_cols <- grep("Date", names(df), ignore.case = TRUE)
  
  # 2. Convert only those columns to character yyyy-mm-dd
  df[date_cols] <- lapply(df[date_cols], function(x) {
    format(as.Date(x), "%Y-%m-%d")
  })
  
  return(df)
})

# %% [markdown]
# ### Task 1
#
# For each time series we **discard every column other than "Date" and "Close"**

# %%
trimmed_list <- lapply(list_of_dfs, function(df) {
  df[, c("Date", "Close")]
})

# %% [markdown]
# We check the results and correctness

# %%
lapply(trimmed_list, head)

lapply(trimmed_list, nrow)
# Out:
# $`33551440_AFL`
#         Date  Close
# 1 2019-01-02 38.411
# 2 2019-01-03 37.441
# 3 2019-01-04 37.905
# 4 2019-01-07 38.107
# 5 2019-01-08 38.225
# 6 2019-01-09 38.141
#
# $`33551440_ALGN`
#         Date  Close
# 1 2019-01-02 202.12
# 2 2019-01-03 184.78
# 3 2019-01-04 186.71
# 4 2019-01-07 189.92
# 5 2019-01-08 192.95
# 6 2019-01-09 200.32
#
# $`33551440_C`
#         Date  Close
# 1 2019-01-02 41.633
# 2 2019-01-03 40.878
# 3 2019-01-04 42.877
# 4 2019-01-07  43.25
# 5 2019-01-08 43.134
# 6 2019-01-09 43.849
#
# $`33551440_CAT`
#         Date   Close
# 1 2019-01-02 108.229
# 2 2019-01-03 104.059
# 3 2019-01-04 109.745
# 4 2019-01-07 109.814
# 5 2019-01-08 111.132
# 6 2019-01-09 111.561
#
# $`33551440_CZR`
#         Date Close
# 1 2019-01-02 37.95
# 2 2019-01-03 37.38
# 3 2019-01-04 39.45
# 4 2019-01-07  40.8
# 5 2019-01-08 42.18
# 6 2019-01-09 42.15
#
# $`33551440_HIG`
#         Date  Close
# 1 2019-01-02 37.193
# 2 2019-01-03 36.679
# 3 2019-01-04 37.810
# 4 2019-01-07 37.673
# 5 2019-01-08 37.167
# 6 2019-01-09 37.493
#
# $`33551440_ORCL`
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 40.25007
# 3 2019-01-04 41.94768
# 4 2019-01-07 42.60785
# 5 2019-01-08 42.99171
# 6 2019-01-09 42.90172
#
# $`33551440_TMO`
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 208.2297
# 3 2019-01-04 217.4348
# 4 2019-01-07 220.3467
# 5 2019-01-08 225.4157
# 6 2019-01-09 231.6129
#
# $`33551440_TSCO`
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 14.42036
# 3 2019-01-04 14.71331
# 2 2019-01-03 49.612
# 3 2019-01-04 50.112
# 4 2019-01-07 49.987
# 5 2019-01-08 50.902
# 6 2019-01-09 50.628
#
# $`73123255_MRK`
#         Date  Close
# 1 2019-01-02 58.065
# 2 2019-01-03 56.874
# 3 2019-01-04 58.587
# 4 2019-01-07 57.942
# 5 2019-01-08 58.372
# 6 2019-01-09 57.927
#
# $`73123255_NOC`
#         Date   Close
# 1 2019-01-02 218.933
# 2 2019-01-03 213.202
# 3 2019-01-04 220.293
# 4 2019-01-07 222.008
# 5 2019-01-08 223.012
# 6 2019-01-09 224.070
#
# $`73123255_ON`
#         Date Close
# 1 2019-01-02 16.78
# 2 2019-01-03 15.65
# 3 2019-01-04 16.50
# 4 2019-01-07 17.00
# 5 2019-01-08 16.54
# 6 2019-01-09 17.81
#
# $`73123255_ORCL`
#         Date  Close
# 1 2019-01-02 40.647
# 2 2019-01-03 40.252
# 3 2019-01-04 41.986
# 4 2019-01-07 42.652
# 5 2019-01-08 43.038
# 6 2019-01-09 42.948
#
# $`73123255_TFC`
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 31.95726
# 3 2019-01-04 32.78640
# 4 2019-01-07 33.04627
# 5 2019-01-08 33.12614
# 6 2019-01-09 33.43656
# $`33551440_AFL`
# [1] 1754
#
# $`33551440_ALGN`
# [1] 1759
#
# $`33551440_C`
# [1] 1759
#
# $`33551440_CAT`
# [1] 1759
#
# $`33551440_CZR`
# [1] 1759
#
# $`33551440_HIG`
# [1] 1759
#
# $`33551440_ORCL`
# [1] 1756
#
# $`33551440_TMO`
# [1] 1759
#
# $`33551440_TSCO`
# [1] 1759
#
# $`33551440_WAT`
# [1] 1759
#
# $`70701808_AMCR`
# [1] 1759
#
# $`70701808_AME`
# [1] 1759
#
# $`70701808_BA`
# [1] 1757
#
# $`70701808_EQT`
# [1] 1759
#
# $`70701808_KIM`
# [1] 1756
#
# $`70701808_KMI`
# [1] 1756
#
# $`70701808_LOW`
# [1] 1758
#
# $`70701808_MS`
# [1] 1759
#
# $`70701808_PCAR`
# [1] 1759
#
# $`70701808_WAT`
# [1] 1759
#
# $`73123255_CSGP`
# [1] 1756
#
# $`73123255_CTRA`
# [1] 1757
#
# $`73123255_ES`
# [1] 1759
#
# $`73123255_MRK`
# [1] 1759
#
# $`73123255_NOC`
# [1] 1759
#
# $`73123255_ON`
# [1] 1757
#
# $`73123255_ORCL`
# [1] 1758
#
# $`73123255_TFC`
# [1] 1759

# %% [markdown]
# **data cleaning:** Some Close columns are stored as characters, let us look into that first and see what causes that. We are checking rows which are not recognized by the as.numeric function:

# %%
filtered_results <- Filter(length, lapply(trimmed_list, function(df) {
  
  broken_rows <- suppressWarnings(is.na(as.numeric(df$Close)))
  
  actual_typos <- broken_rows & !is.na(df$Close)
  
  unique(df$Close[actual_typos])
}))

filtered_results
# Out:
# $`33551440_ALGN`
# [1] "whoops"
#
# $`33551440_C`
# [1] "whoops"
#
# $`33551440_CZR`
# [1] "whoops"
#
# $`70701808_BA`
# [1] "whoops"
#
# $`70701808_KIM`
# [1] "whoops"
#
# $`73123255_CSGP`
# [1] "whoops"

# %% [markdown]
# We found the trickery in the data, let us treat these as NAs from now on

# %%
#convert all Close to numeric, the whoops will be turned into NA
numeric_list <- lapply(trimmed_list, function(df) {
  df$Close <- suppressWarnings(as.numeric(df$Close))
  return(df)
})

# %% [markdown]
# Now we rerun the numeric check to see if the whoops rows were correctly transformed

# %%
filtered_results_2 <- Filter(length, lapply(numeric_list, function(df) {
  
  broken_rows <- suppressWarnings(is.na(as.numeric(df$Close)))
  
  actual_typos <- broken_rows & !is.na(df$Close)
  
  unique(df$Close[actual_typos])
}))

filtered_results_2
# Out:
# named list()

# %% [markdown]
# **data cleaning:** The result is an empty list, so the transformation worked. We move on to detecting NA values

# %%
#locate each NA and print the surrounding rows
for (stock_name in names(numeric_list)) {
  
  df <- numeric_list[[stock_name]]
  
  na_rows <- which(is.na(df$Close))
  
  if (length(na_rows) > 0) {
    cat("\n=== NAs found in:", stock_name, "===\n")
    
    for (i in na_rows) {
      rows_to_print <- max(1, i - 2) : min(nrow(df), i + 2)
      
      cat("--> NA located at Row", i, ":\n")
      print(df[rows_to_print, ])
      cat("\n")
    }
  }
}
# Out:
# === NAs found in: 33551440_ALGN ===
# --> NA located at Row 224 :
#           Date  Close
# 222 2019-11-15 263.92
# 223 2019-11-18 268.51
# 224 2019-11-19     NA
# 225 2019-11-20 268.77
# 226 2019-11-21 272.14
#
#
# === NAs found in: 33551440_C ===
# --> NA located at Row 793 :
#           Date  Close
# 791 2022-02-18 55.436
# 792 2022-02-22 55.220
# 793 2022-02-23     NA
# 794 2022-02-24 52.437
# 795 2022-02-25 53.569
#
#
# === NAs found in: 33551440_CZR ===
# --> NA located at Row 1145 :
#            Date Close
# 1143 2023-07-18 56.35
# 1144 2023-07-19 57.68
# 1145 2023-07-20    NA
# 1146 2023-07-21 57.73
# 1147 2023-07-24 57.77
#
#
# === NAs found in: 33551440_ORCL ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 40.25007
# 3 2019-01-04 41.94768
#
#
# === NAs found in: 33551440_TMO ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 208.2297
# 3 2019-01-04 217.4348
#
#
# === NAs found in: 33551440_TSCO ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 14.42036
# 3 2019-01-04 14.71331
#
#
# === NAs found in: 33551440_WAT ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 176.2001
# 3 2019-01-04 179.6043
#
#
# === NAs found in: 70701808_AME ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 62.55744
# 3 2019-01-04 64.87979
#
#
# === NAs found in: 70701808_BA ===
# --> NA located at Row 656 :
#           Date  Close
# 654 2021-08-06 231.33
# 655 2021-08-09 232.27
# 656 2021-08-10     NA
# 657 2021-08-11 239.49
# 658 2021-08-12 238.18
#
#
# === NAs found in: 70701808_KIM ===
# --> NA located at Row 1169 :
#            Date  Close
# 1167 2023-08-23 16.739
# 1168 2023-08-24 16.580
# 1169 2023-08-25     NA
# 1170 2023-08-28 16.624
# 1171 2023-08-29 16.695
#
#
# === NAs found in: 73123255_CSGP ===
# --> NA located at Row 1086 :
#            Date Close
# 1084 2023-04-26 71.92
# 1085 2023-04-27 77.17
# 1086 2023-04-28    NA
# 1087 2023-05-01 76.11
# 1088 2023-05-02 74.75
#
#
# === NAs found in: 73123255_CTRA ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 17.34565
# 3 2019-01-04 17.15865
#
#
# === NAs found in: 73123255_TFC ===
# --> NA located at Row 1 :
#         Date    Close
# 1 2019-01-02       NA
# 2 2019-01-03 31.95726
# 3 2019-01-04 32.78640

# %% [markdown]
# Most of the tickers have at least one NA, but the amount of NAs is minimal compared to the amount of observations. Therefore we have opted to keep NAs as they are and will not delete the whole rows for now as it might be useful further along.

# %% [markdown]
# The data cleaning is almost done, let us now check why some data frames are shorter than others. All start at the same date so we check the ending dates for all the data frames

# %%
ending_dates <- sapply(numeric_list, function(df) {
  tail(df$Date, 1)
})

print(ending_dates)
# Out:
#  33551440_AFL 33551440_ALGN    33551440_C  33551440_CAT  33551440_CZR
#  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"
#  33551440_HIG 33551440_ORCL  33551440_TMO 33551440_TSCO  33551440_WAT
#  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"
# 70701808_AMCR  70701808_AME   70701808_BA  70701808_EQT  70701808_KIM
#  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"
#  70701808_KMI  70701808_LOW   70701808_MS 70701808_PCAR  70701808_WAT
#  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"
# 73123255_CSGP 73123255_CTRA   73123255_ES  73123255_MRK  73123255_NOC
#  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"  "2025-12-30"
#   73123255_ON 73123255_ORCL  73123255_TFC
#  "2025-12-30"  "2025-12-30"  "2025-12-30"

# %% [markdown]
# **data cleaning:** the stocks data start and end at the same date so the problem is somewhere inside, we look into that by comparing all the avaible dates to each of the stock

# %%
all_dates <- unlist(lapply(numeric_list, function(df) df$Date))

# 2. Extract only the unique dates to build our true Master Calendar, and sort them
true_master_calendar <- sort(unique(all_dates))

cat("Total unique dates across ALL stocks:", length(true_master_calendar), "\n")

# 3. Loop through and compare each stock to the true Master Calendar
for (stock_name in names(numeric_list)) {
  
  stock_dates <- numeric_list[[stock_name]]$Date
  
  missing_dates <- setdiff(true_master_calendar, stock_dates)
  
  if (length(missing_dates) > 0) {
    cat("\n=== Missing dates in:", stock_name, "===\n")
    print(missing_dates)
  }
}
# Out:
# Total unique dates across ALL stocks: 1759
#
# === Missing dates in: 33551440_AFL ===
# [1] "2020-03-10" "2020-08-07" "2023-05-26" "2023-11-28" "2024-02-23"
#
# === Missing dates in: 33551440_ORCL ===
# [1] "2021-09-17" "2025-03-07" "2025-11-13"
#
# === Missing dates in: 70701808_BA ===
# [1] "2020-02-11" "2023-08-01"
#
# === Missing dates in: 70701808_KIM ===
# [1] "2020-04-01" "2020-11-25" "2025-12-08"
#
# === Missing dates in: 70701808_KMI ===
# [1] "2019-11-13" "2021-03-19" "2023-03-03"
#
# === Missing dates in: 70701808_LOW ===
# [1] "2022-02-11"
#
# === Missing dates in: 73123255_CSGP ===
# [1] "2019-05-07" "2022-04-13" "2022-12-15"
#
# === Missing dates in: 73123255_CTRA ===
# [1] "2021-06-30" "2024-08-20"
#
# === Missing dates in: 73123255_ON ===
# [1] "2024-10-01" "2025-12-16"
#
# === Missing dates in: 73123255_ORCL ===
# [1] "2024-05-09"

# %% [markdown]
# Some dates for these stocks are missing, we did not find a valuable reason for it. We keep the time series as it is for now but we will keep it in mind for later processes

# %% [markdown]
# **data cleaning:** Lastly we need to check if there are Dates duplicates

# %%
for (ticker in names(numeric_list)) {
  
  # Find dates that appear more than once
  duplicate_dates <- numeric_list[[ticker]]$Date[duplicated(numeric_list[[ticker]]$Date)]
  
  # Only print if duplicates actually exist
  if (length(duplicate_dates) > 0) {
    cat("Ticker:", ticker, "\n")
    print(unique(duplicate_dates))
    cat("\n")
  }
}

# %% [markdown]
# No dates duplicates have been found

# %% [markdown]
# ### Task 2

# %% [markdown]
# **Now we add the returns and log returns**

# %%
returns_list <- lapply(numeric_list, function(df) {
  df %>%
    mutate(Close = as.numeric(Close)) %>%
    mutate(
      rets_simple = (Close / lag(Close)) - 1,
      rets = log(Close / lag(Close))
    )
})

# %%
lapply(returns_list, head)
# Out:
# $`33551440_AFL`
#         Date  Close  rets_simple         rets
# 1 2019-01-02 38.411           NA           NA
# 2 2019-01-03 37.441 -0.025253183 -0.025577516
# 3 2019-01-04 37.905  0.012392831  0.012316669
# 4 2019-01-07 38.107  0.005329112  0.005314963
# 5 2019-01-08 38.225  0.003096544  0.003091760
# 6 2019-01-09 38.141 -0.002197515 -0.002199933
#
# $`33551440_ALGN`
#         Date  Close rets_simple        rets
# 1 2019-01-02 202.12          NA          NA
# 2 2019-01-03 184.78 -0.08579062 -0.08969565
# 3 2019-01-04 186.71  0.01044485  0.01039068
# 4 2019-01-07 189.92  0.01719244  0.01704632
# 5 2019-01-08 192.95  0.01595409  0.01582816
# 6 2019-01-09 200.32  0.03819642  0.03748500
#
# $`33551440_C`
#         Date  Close  rets_simple         rets
# 1 2019-01-02 41.633           NA           NA
# 2 2019-01-03 40.878 -0.018134653 -0.018301101
# 3 2019-01-04 42.877  0.048901610  0.047743531
# 4 2019-01-07 43.250  0.008699303  0.008661682
# 5 2019-01-08 43.134 -0.002682081 -0.002685684
# 6 2019-01-09 43.849  0.016576251  0.016440364
#
# $`33551440_CAT`
#         Date   Close   rets_simple          rets
# 1 2019-01-02 108.229            NA            NA
# 2 2019-01-03 104.059 -0.0385294145 -0.0392913067
# 3 2019-01-04 109.745  0.0546420781  0.0532014469
# 4 2019-01-07 109.814  0.0006287302  0.0006285327
# **Plotting the returns** and since ggplot2 cannot work with the list of data frames, we will bind the into onle long data frame

# %%
combined_returns0 <- bind_rows(returns_list, .id = "Ticker")

# 2. Make sure R knows the Date column represents actual dates (not text)
combined_returns0 <- combined_returns0 %>%
  mutate(Date = as.Date(Date))

ggplot(combined_returns0, aes(x = Date, y = rets, color = Ticker)) +
  geom_line(alpha = 0.7, linewidth = 0.3) + 
  theme_minimal() +
  labs(
    title = "Logarithmic Returns of All Stocks",
    x = "Date",
    y = "Logarithmic Return",
    color = "Stock"
  ) +
  theme(legend.position = "bottom")
# Out:
# Warning message:
# "Removed 35 rows containing missing values or values outside the scale range
# (`geom_line()`)."
# plot without title

# %% [markdown]
# The extreme logarithmic returns in some cases suggest at most roughly 170% daily stock price increase, in negative cases abouyt 70% stock price daily decrease. Such values are very unlikely. Furthermore a returns spike in one direction is followed by a spike in the other direction (seen in the chart). The following code inspects how the data looks around these spikes

# %%
# Loop through each stock in your list
for (stock_name in names(returns_list)) {
  
  df <- returns_list[[stock_name]]
  
  spike_rows <- which(abs(df$rets) > 0.4)
  
  # If we found any spikes, print them out
  if (length(spike_rows) > 0) {
    cat("\n=== Spikes found in:", stock_name, "===\n")
    
    for (row_idx in spike_rows) {
      # Calculate the window (ensuring we don't go below row 1 or past the end)
      start_row <- max(1, row_idx - 2)
      end_row <- min(nrow(df), row_idx + 2)
      
      # Print the 5-row window
      print(df[start_row:end_row, ])
      cat("--------------------\n")
    }
  }
}
# Out:
# === Spikes found in: 33551440_ALGN ===
#            Date  Close  rets_simple         rets
# 1652 2025-07-29 205.81 -0.006660553 -0.006682834
# 1653 2025-07-30 203.57 -0.010883825 -0.010943487
# 1654 2025-07-31 129.01 -0.366262219 -0.456120005
# 1655 2025-08-01 136.52  0.058212542  0.056581203
# 1656 2025-08-04 137.77  0.009156168  0.009114504
# --------------------
#
# === Spikes found in: 33551440_CAT ===
#          Date    Close  rets_simple         rets
# 56 2019-03-22 111.8470 -0.032004847 -0.032528199
# 57 2019-03-25 113.2350  0.012409810  0.012333439
# 58 2019-03-26 338.1927  1.986644728  1.094150593
# 59 2019-03-27 113.0800 -0.665634431 -1.095520365
# 60 2019-03-28 114.0880  0.008914043  0.008874548
# --------------------
#          Date    Close  rets_simple         rets
# 57 2019-03-25 113.2350  0.012409810  0.012333439
# 58 2019-03-26 338.1927  1.986644728  1.094150593
# 59 2019-03-27 113.0800 -0.665634431 -1.095520365
# 60 2019-03-28 114.0880  0.008914043  0.008874548
# 61 2019-03-29 116.7770  0.023569525  0.023296053
# --------------------
#           Date    Close  rets_simple         rets
# 165 2019-08-27  99.0700 -0.009091909 -0.009133493
# 166 2019-08-28 100.3630  0.013051378  0.012966942
# 167 2019-08-29 293.4486  1.923872231  1.072908844
# 168 2019-08-30 103.9800 -0.645661952 -1.037503885
# 169 2019-09-03 102.2590 -0.016551260 -0.016689762
# --------------------
#           Date    Close rets_simple        rets
# 166 2019-08-28 100.3630  0.01305138  0.01296694
# 167 2019-08-29 293.4486  1.92387223  1.07290884
# 168 2019-08-30 103.9800 -0.64566195 -1.03750388
# 428 2020-09-11 203.93000  1.766466300  1.017570802
# 429 2020-09-14 205.28000  0.006619919  0.006598103
# 430 2020-09-15 205.61000  0.001607560  0.001606270
# --------------------
#
# === Spikes found in: 73123255_ORCL ===
#          Date    Close  rets_simple         rets
# 26 2019-02-07 45.32000 -0.020298753 -0.020507603
# 27 2019-02-08 46.05100  0.016129744  0.016001042
# 28 2019-02-11 16.29609 -0.646129541 -1.038824369
# 29 2019-02-12 46.22300  1.836447534  1.042552401
# 30 2019-02-13 46.40300  0.003894165  0.003886603
# --------------------
#          Date    Close  rets_simple         rets
# 27 2019-02-08 46.05100  0.016129744  0.016001042
# 28 2019-02-11 16.29609 -0.646129541 -1.038824369
# 29 2019-02-12 46.22300  1.836447534  1.042552401
# 30 2019-02-13 46.40300  0.003894165  0.003886603
# 31 2019-02-14 46.45700  0.001163718  0.001163041
# --------------------
#           Date    Close rets_simple         rets
# 642 2021-07-20 83.46000  0.01932143  0.019137141
# 643 2021-07-21 84.42900  0.01161035  0.011543469
# 644 2021-07-22 26.43543 -0.68689161 -1.161205856
# 645 2021-07-23 82.54700  2.12258986  1.138662740
# 646 2021-07-26 82.70700  0.00193829  0.001936414
# --------------------
#           Date    Close   rets_simple          rets
# 643 2021-07-21 84.42900  0.0116103523  0.0115434693
# 644 2021-07-22 26.43543 -0.6868916105 -1.1612058562
# 645 2021-07-23 82.54700  2.1225898567  1.1386627398
# 646 2021-07-26 82.70700  0.0019382897  0.0019364136
# 647 2021-07-27 82.65000 -0.0006891799 -0.0006894175
# --------------------
#            Date     Close  rets_simple         rets
# 1669 2025-08-22 235.33800  0.013767435  0.013673525
# 1670 2025-08-25 234.38300 -0.004057993 -0.004066249
# 1671 2025-08-26  90.41424 -0.614245733 -0.952554725
# 1672 2025-08-27 234.78100  1.596725843  0.954251360
# 1673 2025-08-28 239.27100  0.019124205  0.018943636
# --------------------
#            Date     Close  rets_simple         rets
# 1670 2025-08-25 234.38300 -0.004057993 -0.004066249
# 1671 2025-08-26  90.41424 -0.614245733 -0.952554725
# 1672 2025-08-27 234.78100  1.596725843  0.954251360
# 1673 2025-08-28 239.27100  0.019124205  0.018943636
# 1674 2025-08-29 225.14300 -0.059046019 -0.060861045
# --------------------

# %% [markdown]
# **data cleaning:** We will treat values with **logarithmic returns that are over 0.9 (abs) as NAs**, data shows that it is a consequence of a measurement error or error in the data

# %%
for (ticker in names(returns_list)) {
  
  # Find rows where rets is strictly greater than 0.9 or less than -0.9
  bad_rows <- which(returns_list[[ticker]]$rets > 0.9 | returns_list[[ticker]]$rets < -0.9)
  
  # If any such rows exist, replace Close, rets, and rets_simple with NA
  if (length(bad_rows) > 0) {
    returns_list[[ticker]]$Close[bad_rows] <- NA
    returns_list[[ticker]]$rets[bad_rows] <- NA
    returns_list[[ticker]]$rets_simple[bad_rows] <- NA
  }
}

# %% [markdown]
# **recompute the rets and rets_simple**

# %%
returns_list2 <- lapply(returns_list, function(df) {
  df %>%
    mutate(Close = as.numeric(Close)) %>%
    mutate(
      rets_simple = (Close / lag(Close)) - 1,
      rets = log(Close / lag(Close))
    )
})

# %% [markdown]
# **plotting cleaned returns from outliers**

# %%
combined_returns <- bind_rows(returns_list2, .id = "Ticker")

# 2. Make sure R knows the Date column represents actual dates (not text)
combined_returns <- combined_returns %>%
  mutate(Date = as.Date(Date))

ggplot(combined_returns, aes(x = Date, y = rets, color = Ticker)) +
  geom_line(alpha = 0.7, linewidth = 0.3) + 
  theme_minimal() +
  labs(
    title = "Logarithmic Returns of All Stocks",
    x = "Date",
    y = "Logarithmic Return",
    color = "Stock"
  ) +
  theme(legend.position = "bottom")
# Out:
# Warning message:
# “Removed 35 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# plot without title

# %% [markdown]
# Now the values look more like we would expect.

# %% [markdown]
# ### Task 4

# %% [markdown]
# lets now **compute all the descriptive statistics** that are needed to get an overview of the data

# %%
summary_stats <- combined_returns %>%
  group_by(Ticker) %>%
  filter(!is.na(rets)) %>%
  summarise(
    Mean = mean(rets),
    Std_Dev = sd(rets),
    Minimum = min(rets),
    Maximum = max(rets),
    Skewness = skewness(rets),
    Kurtosis = kurtosis(rets)
  )

print(summary_stats, n = Inf)
# Out:
# # A tibble: 28 × 7
#    Ticker             Mean Std_Dev Minimum Maximum Skewness Kurtosis
#    <chr>             <dbl>   <dbl>   <dbl>   <dbl>    <dbl>    <dbl>
#  1 33551440_AFL   0.000601  0.0181  -0.179  0.233   -0.263     33.5
#  2 33551440_ALGN -0.000140  0.0340  -0.456  0.300   -1.66      32.3
#  3 33551440_C     0.000616  0.0230  -0.214  0.165   -0.545     13.3
#  4 33551440_CAT   0.000937  0.0200  -0.154  0.110   -0.260      5.19
#  5 33551440_CZR  -0.000273  0.0427  -0.470  0.366   -0.966     20.3
#  6 33551440_HIG   0.000749  0.0204  -0.238  0.244   -0.505     37.8
#  7 33551440_ORCL -0.000658  0.0283  -0.263  0.268   -2.58      31.6
#  8 33551440_TMO  -0.000818  0.0244  -0.270  0.0949  -4.51      42.8
#  9 33551440_TSCO -0.000673  0.0248  -0.261  0.0964  -4.24      36.3
# 10 33551440_WAT   0.00136   0.0252  -0.161  0.252    2.63      24.8
# 11 70701808_AMCR  0.000114  0.0175  -0.176  0.151   -0.756     17.5
# 12 70701808_AME  -0.000842  0.0244  -0.277  0.144   -5.63      54.7
# 13 70701808_BA   -0.000225  0.0296  -0.272  0.218   -0.392     13.5
# 14 70701808_EQT   0.000618  0.0336  -0.207  0.317    0.436      6.58
# 15 70701808_KIM   0.000372  0.0236  -0.221  0.280    0.0115    22.3
# 16 70701808_KMI   0.000550  0.0187  -0.236  0.155   -1.85      28.0
# 17 70701808_LOW   0.000625  0.0196  -0.285  0.131   -1.97      30.6
# 18 70701808_MS    0.000971  0.0210  -0.170  0.180    0.0552    12.4
# 19 70701808_PCAR  0.000747  0.0170  -0.116  0.133    0.278      6.18
# 20 70701808_WAT   0.000484  0.0204  -0.149  0.181    0.210      8.79
# 21 73123255_CSGP  0.000411  0.0214  -0.163  0.146    0.0655     7.85
# 22 73123255_CTRA -0.00133   0.0290  -0.302  0.136   -2.89      23.9
# 23 73123255_ES    0.000175  0.0169  -0.137  0.138   -0.430     13.4
# 24 73123255_MRK   0.000343  0.0151  -0.104  0.0804  -0.458      6.92
# 25 73123255_NOC   0.000547  0.0169  -0.135  0.122   -0.217      9.72
# 26 73123255_ON    0.000668  0.0349  -0.313  0.218   -0.463      8.60
# 27 73123255_ORCL  0.000898  0.0228  -0.148  0.307    1.50      27.5
# 28 73123255_TFC  -0.00129   0.0294  -0.262  0.148   -3.04      24.1

# %% [markdown]
# Based on the descriptive statistics, the mean logarithmic returns across all time series are appropriately close to zero, with standard deviations reflecting typical daily equity volatility (ranging from roughly 1.5% to 4.2%). However, the higher-order moments and extreme values strongly indicate lingering data issues. Almost all stocks exhibit extreme leptokurtosis (fat tails), with kurtosis values far exceeding the normal distribution baseline of 3 (e.g., AME at 54.7 and TMO at 42.8). Furthermore, several series display highly suspicious minimum and maximum daily log returns, such as CZR's -0.470 (a ~37% single-day drop) and ALGN's -0.456. Coupled with pronounced negative skewness across the board.

# %% [markdown]
# ### Task 5

# %% [markdown]
# The AME is the ticker with highest observer kurtosis and skeweness. With all tickers having similar mean and variance we select this as the **time series most strongly departing from normality**

# %%
options(repr.plot.width = 10, repr.plot.height = 6, repr.plot.res = 300)

# %%
AME_rets <- combined_returns %>%
  filter(Ticker == "70701808_AME" & !is.na(rets)) %>%
  pull(rets)

mu <- mean(AME_rets)
sigma <- sd(AME_rets)

stable_fit <- stableFit(AME_rets, doplot = FALSE)

alpha_fit <- stable_fit@fit$estimate["alpha"]
beta_fit  <- stable_fit@fit$estimate["beta"]
gamma_fit <- stable_fit@fit$estimate["gamma"]
delta_fit <- stable_fit@fit$estimate["delta"]

ggplot(data.frame(rets = AME_rets), aes(x = rets)) +
  geom_histogram(aes(y = after_stat(density)), bins = 100, fill = "lightgray", color = "black") +
  
  stat_function(fun = dnorm, args = list(mean = mu, sd = sigma), 
                color = "red", linewidth = 1, linetype = "dashed",n = 1000) +
  
  stat_function(fun = dstable, 
                args = list(alpha = alpha_fit, beta = beta_fit, 
                            gamma = gamma_fit, delta = delta_fit), 
                color = "blue", linewidth = 1,n = 1000) +
  
  theme_minimal() +
  coord_cartesian(xlim = c(-0.2, 0.2)) + # Zoom in to see the peak clearly 
  labs(
    title = "Density of AME Log Returns: Normal vs. Stable Distribution",
    subtitle = "Red Dashed = Normal | Blue Solid = Stable",
    x = "Logarithmic Returns",
    y = "Density"
  )
# Out:
# plot without title

# %% [markdown]
# The returns for AME show a clear departure from normality, characterized by significant excess kurtosis. We observe a higher peak and heavier tails than the normal curve. There is less density in the regions surrounding the mean compared to the normal distribution. The fitted stable distribution provides a significantly better fit for the empirical density than the normal distribution.

# %% [markdown]
# ### Part 2

# %% [markdown]
# **data cleaning:** We put the time series into same data frame and keep only the dates where all the tickers have values

# %%
wide_returns <- combined_returns %>%
  select(Date, Ticker, rets) %>%
  pivot_wider(names_from = Ticker, values_from = rets)

clean_wide_returns <- wide_returns %>%
  drop_na()

# %%
head(clean_wide_returns)
# Out:
#   Date       33551440_AFL 33551440_ALGN 33551440_C   33551440_CAT
# 1 2019-01-04  0.012316669  0.01039068    0.047743531  0.0532014469
# 2 2019-01-07  0.005314963  0.01704632    0.008661682  0.0006285327
# 3 2019-01-08  0.003091760  0.01582816   -0.002685684  0.0119306585
# 4 2019-01-09 -0.002199933  0.03748500    0.016440364  0.0038528425
# 5 2019-01-10  0.012532243  0.01151492    0.001071286  0.0204332273
# 6 2019-01-11 -0.001762206 -0.02190215    0.004409800 -0.0064848328
#   33551440_CZR  33551440_HIG 33551440_ORCL 33551440_TMO 33551440_TSCO ⋯
# 1  0.0538982453  0.030369234  0.041311351  0.043257100   0.0201114243 ⋯
# 2  0.0336480341 -0.003629960  0.015615380  0.013303339   0.0145291686 ⋯
# 3  0.0332640936 -0.013522387  0.008968939  0.022743837  -0.0006029343 ⋯
# 4 -0.0007114906  0.008732978 -0.002095559  0.027121305   0.0132217787 ⋯
# 5  0.0124957420  0.010216220  0.000837521  0.010338735   0.0005946089 ⋯
# 6  0.0039752186  0.005423778  0.009745127  0.004752244   0.0074754796 ⋯
#   70701808_PCAR 70701808_WAT 73123255_CSGP 73123255_CTRA 73123255_ES
# 1  0.043455101  0.019319931   0.0340329290 -0.010839373   0.0100277604
# 2 -0.001186513  0.040657335   0.0095522939  0.039096179  -0.0024975287
# 3  0.009616248  0.027133345   0.0089402014  0.014296454   0.0181392439
# 4 -0.015238327  0.013115958   0.0241458694 -0.023908673  -0.0053974326
# 5  0.009013085  0.010410913   0.0175605511  0.011232425   0.0198886025
# 6  0.004721630  0.006426985  -0.0009737235  0.002452759  -0.0009104734
#   73123255_MRK 73123255_NOC 73123255_ON 73123255_ORCL 73123255_TFC
# 1  0.029674534  0.032718405  0.05288946  0.0421765373  0.025614136
# 2 -0.011070319  0.007754939  0.02985296  0.0157379368  0.007895058
# 3  0.007393813  0.004512164 -0.02743165  0.0090092802  0.002414076
# 4 -0.007652726  0.004732921  0.07397841 -0.0020933648  0.009327211
# 5 -0.012419931  0.021615018  0.00448180  0.0008378719 -0.006347816
# 6  0.005629792 -0.006269448  0.03298815  0.0097927650 -0.005475087

# %% [markdown]
# We try to get a broad picture of how many rows we removed

# %%
# Count total rows removed
rows_removed <- nrow(wide_returns) - nrow(clean_wide_returns)

# Count how many columns had at least one NA
cols_with_na <- wide_returns %>%
  select(-Date) %>%          # skip the Date column
  summarise(across(everything(), ~ any(is.na(.)))) %>%
  unlist() %>%
  sum()

# Find column with the most NAs
na_per_col <- wide_returns %>%
  select(-Date) %>%
  summarise(across(everything(), ~ sum(is.na(.)))) %>%
  pivot_longer(everything(), names_to = "column", values_to = "na_count") %>%
  arrange(desc(na_count))

top_na_col <- na_per_col$column[1]
top_na_count <- na_per_col$na_count[1]

# Create the summary tibble
tibble(
  dataframe = "wide_returns",
  original_rows = nrow(wide_returns),
  cleaned_rows  = nrow(clean_wide_returns),
  rows_removed  = rows_removed,
  columns_with_na_removed = cols_with_na,
  column_most_nas = top_na_col,
  n_removed_from_column = top_na_count
)
# Out:
#   dataframe    original_rows cleaned_rows rows_removed columns_with_na_removed
# 1 wide_returns 1759          1695         64           28
#   column_most_nas n_removed_from_column
# 1 73123255_ORCL   11

# %% [markdown]
# A total of 64 rows were excluded, distributed across 28 different columns. This indicates that missing observations were generally sparse within individual columns. The column with the highest number of missing values was 73123255_ORCL, which accounted for 11 missing entries. However, considering the overall length of the time series, this number is relatively small. Therefore, we conclude that the row removals at this stage are unlikely to have a significant impact on the analysis.

# %% [markdown]
# Now we compute the cross sectional mean logarithmic return for each date

# %%
mean_series <- clean_wide_returns %>%
  mutate(cross_sectional_mean = rowMeans(select(., -Date))) %>%
  select(Date, cross_sectional_mean)


head(mean_series)
# Out:
#   Date       cross_sectional_mean
# 1 2019-01-04 0.029610658
# 2 2019-01-07 0.014259079
# 3 2019-01-08 0.011535746
# 4 2019-01-09 0.007027722
# 5 2019-01-10 0.007267583
# 6 2019-01-11 0.003386006

# %% [markdown]
# **2: Estimating the parameters of a stable distribution**

# %%
mean_returns_vec <- mean_series$cross_sectional_mean

mean_stable_fit <- stableFit(mean_returns_vec, doplot = FALSE)

mean_params <- mean_stable_fit@fit$estimate
print("Parameters for Cross-Sectional Mean Returns:")
print(mean_params)
# Out:
# [1] "Parameters for Cross-Sectional Mean Returns:"
#         alpha          beta         gamma         delta
#  1.5510000000 -0.1430000000  0.0067423875  0.0007041332

# %% [markdown]
# We compare these values to the estimated parameters of the series 70701808_AME

# %%
# Pretty print
cat("Estimated stable distribution parameters for the series 70701808_AME:\n")
cat(sprintf("Alpha (stability):      %.4f\n", alpha_fit))
cat(sprintf("Beta (skewness):       %.4f\n", beta_fit))
cat(sprintf("Gamma (scale):         %.4f\n", gamma_fit))
cat(sprintf("Delta (location):      %.4f\n", delta_fit))
# Out:
# Estimated stable distribution parameters for the series 70701808_AME:
# Alpha (stability):      1.5450
# Beta (skewness):       -0.1600
# Gamma (scale):         0.0078
# Delta (location):      0.0012

# %% [markdown]
# Now we compare the estimated parameters:
#
# * The alpha parameter measures the **heavy-tailedness**. The AME series has a lower alpha than the mean return series, indicating slightly heavier tails. Since the AME series was identified as the series that departs most strongly from normality, heavier tails are expected. This implies a higher probability of extreme returns relative to the cross-sectional mean series. In contrast, the higher alpha of the mean return series suggests that aggregation reduces tail risk and results in a distribution closer to normality.
# * The beta parameter controls for **asymmetry of the distribution**. The AME series is more left-skewed than the mean return series, indicating a greater tendency for large negative returns. The negative skewness of the cross-sectional mean series suggests that downside movements still dominate slightly even after aggregation. However, the smaller magnitude of beta for the mean series shows that diversification reduces asymmetry and mitigates extreme negative shocks.
# * The gamma parameter controls the **dispersion of the distribution**. The cross-sectional mean has smaller scale, reflecting aggregation and diversification that smooth out volatility. The individual series exhibits larger scale, signaling higher day-to-day variability in returns.
# * The delta parameter describes the **central tendency of the distribution**. Both parameters are positive and economically small, which is typical for daily returns. The higher $\delta$ for AME indicates that its return distribution is centered at a slightly higher level than the aggregated mean return. This difference reflects asset-specific performance, while aggregation across assets smooths central tendencies.

# %% [markdown]
# **3. Plotting the histogram of the mean-return series**

# %%
mu <- mean(mean_series$cross_sectional_mean, na.rm = TRUE)
sigma <- sd(mean_series$cross_sectional_mean, na.rm = TRUE)

stable_fit <- stableFit(mean_series$cross_sectional_mean, doplot = FALSE)
s_params <- stable_fit@fit$estimate

ggplot(mean_series, aes(x = cross_sectional_mean)) +
  geom_histogram(aes(y = ..density..), bins = 50, fill = "gray", color = "white") +
  
  stat_function(fun = dnorm, 
                args = list(mean = mu, sd = sigma), 
                aes(color = "Normal"), size = 1) +
  
  stat_function(fun = dstable, 
                args = list(alpha = s_params[1], beta = s_params[2], 
                            gamma = s_params[3], delta = s_params[4]), 
                aes(color = "Stable"), size = 1) +
  
  scale_color_manual(name = "Distributions", 
                     values = c("Normal" = "blue", "Stable" = "red")) +
  labs(title = "Cross-Sectional Mean Returns: Normal vs. Stable Fit",
       x = "Log Returns",
       y = "Density") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **4. Computing the descriptive statistics**

# %%
mean_stats <- mean_series %>%
  summarise(
    Mean = mean(cross_sectional_mean),
    Std_Dev = sd(cross_sectional_mean),
    Minimum = min(cross_sectional_mean),
    Maximum = max(cross_sectional_mean),
    Skewness = skewness(cross_sectional_mean),
    Kurtosis = kurtosis(cross_sectional_mean)
  )

print(mean_stats)
# Out:
# # A tibble: 1 × 6
#       Mean Std_Dev Minimum Maximum Skewness Kurtosis
#      <dbl>   <dbl>   <dbl>   <dbl>    <dbl>    <dbl>
# 1 0.000206  0.0143  -0.154   0.128   -0.678     19.3

# %% [markdown]
# The mean of the aggregated series is closer to zero, as positive and negative returns across assets offset each other. The standard deviation is much lower than for individual assets, reflecting diversification (asset-specific shocks cancel out when averaged).
#
# The minimum and maximum values of the mean series are less extreme, showing that aggregation reduces large individual movements.
#
# The skewness of the mean series is still negative, but smaller in magnitude than for many individual assets. This suggests that downside risk remains, though it is less pronounced after averaging.
#
# The kurtosis of the mean series is still high, indicating fat tails, but it is lower than for the most extreme individual assets. Thus, diversification reduces extreme behavior, but does not remove it entirely.
#
# Overall, aggregation leads to lower volatility, weaker asymmetry, and thinner tails compared to individual return series.

# %% [markdown]
# ## Problem 2

# %%
options(repr.plot.width = 16, repr.plot.height = 5)

# %%
# set seed so the results can be replicated

set.seed(1892) # at zije slavie!

# %% [markdown]
# Let us first define our simulation parameters:

# %%
N <- 100    # length of the time series
sims <- 500   # number of realizations

# %% [markdown]
# We define the variance such that the difference is surely going to be visible.
#
# Since the random walk is the cumulative sum of independent random shocks ($Y_t = Y_{t-1} + \varepsilon_t$), the variance of $Y_t$ (the final time point) is the sum of variances of all preceding realisations of $Y$. For a random walk process, we assume that the shocks have equal variance - therefore $\text{Var}(Y_t) = t \cdot \text{Var}(\varepsilon_t) = t \sigma^2$.
#
# The variance of $Y_t$ thus increases linearly over time, so we should expect the standard deviation of $Y_t$ (which is goint to be the trend visible in the plot) to increase in a square root relationship with time - $\sqrt{\text{Var}(Y_t)} = \sigma\sqrt{t}$.

# %%
low_var_matrix <- replicate(sims, cumsum(c(0, rnorm(N, sd = 1))))

high_var_matrix <- replicate(sims, cumsum(c(0, rnorm(N, sd = 2))))

# %% [markdown]
# Now, we proceed to plot the resulting simulated series. To best depict the difference in dispersion across time, we use a spaghetti plot - each simulated series is plotted as a single, partially transparent line, letting us illustrate the density of the distribution at any given time point.

# %%
y_limits <- range(high_var_matrix)
par(mfrow = c(1, 2))

# plot 1: lower variance
matplot(low_var_matrix, 
        type = "l",          
        lty = 1,             
        col = rgb(0, 0, 1, 0.05), 
        ylim = y_limits,     
        main = "Lower Variance", 
        xlab = "Time (N)", 
        ylab = "Value")

# plot 2: higher variance
matplot(high_var_matrix, 
        type = "l", 
        lty = 1, 
        col = rgb(1, 0, 0, 0.05), 
        ylim = y_limits,     
        main = "Higher Variance", 
        xlab = "Time (N)", 
        ylab = "")
# Out:
# Plot with title "Higher Variance"

# %% [markdown]
# Comparing the two plots, the expected pattern of variance increasing over time can be observed. Compared to the series with lower error variance, the dispersion of the higher-error-variance plot increases over time much faster. We can also observe that the relationship between the standard deviation and time seems to take on somewhat of a cone shape. This would be consistent with the expected square-root relationship, implying a linearly increasing variance.

# %%
# calculate percentiles directly for the lower variance matrix
df_low <- data.frame(
  Time = 0:N,
  Type = "Lower variance",
  Q_05 = apply(low_var_matrix, 1, quantile, probs = 0.05), 
  Median = apply(low_var_matrix, 1, median),               
  Q_95 = apply(low_var_matrix, 1, quantile, probs = 0.95)  
)

# calculate percentiles directly for the higher variance matrix
df_high <- data.frame(
  Time = 0:N,
  Type = "Higher variance",
  Q_05 = apply(high_var_matrix, 1, quantile, probs = 0.05), 
  Median = apply(high_var_matrix, 1, median),               
  Q_95 = apply(high_var_matrix, 1, quantile, probs = 0.95)  
)

df_all <- rbind(df_low, df_high)

df_all$Type <- factor(df_all$Type, levels = c("Lower variance", "Higher variance"))

ggplot(df_all, aes(x = Time)) +
  # draw the shaded region between the 5th and 95th percentiles
  geom_ribbon(aes(ymin = Q_05, ymax = Q_95, fill = Type), alpha = 0.3) +
  # draw the median 
  geom_line(aes(y = Median, color = Type), linewidth = 1) +
  
  # facet wrap by type
  facet_wrap(~Type) + 
  
  scale_fill_manual(values = c("Lower variance" = "blue", "Higher variance" = "red")) +
  scale_color_manual(values = c("Lower variance" = "darkblue", "Higher variance" = "darkred")) +
  theme_minimal(base_size = 14) +
  labs(
    title = "Random walk dispersion over time",
    subtitle = "Shaded regions represent the 5th to 95th quantiles across 500 simulations",
    x = "Time step (N)",
    y = "Value"
  ) +
  theme(legend.position = "none", 
        strip.text = element_text(face = "bold", size = 12))
# Out:
# plot without title

# %% [markdown]
# To see the relationship even more clearly, we illustrate the dispersion using the 5th, 50th (median) and 95th percentiles. Exactly as expected, the median (which is supposed to equal the mean in a normal distribution) closely tracks zero, and the shaded region between the two outer quantiles expands outward in a curve that closely resembles a square-root relationship with time.

# %% [markdown]
# ## Disclaimer

# %% [markdown]
# ***Contributions:***
#
# Daniel Ott - Problem 1 Part 1
#
# Anna Turnerová - Problem 1 Part 2
#
# Samuel Šmíd - Problem 2

# %% [markdown]
# ***AI usage:***
#
# The members of this team used ChatGPT to help produce the code, especially for the data cleaning and data visualization parts, as well as for text improvement.
